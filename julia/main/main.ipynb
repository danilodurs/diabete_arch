# %%
using Pkg
Pkg.update()
# Out:
#     Fetching: [========================================>]  100.0 %

# %%
using DataFrames
using Serialization
using ExcelFiles
using Statistics
using Distributions
using CSV
using Plots

include("../models/dalla_man.jl")
include("../param_estim.jl")
# Out:
# update_params

# %%
#############################################
# Various initializations
#############################################

# optimization method

# include("../myOptim/myOptim.jl")
 include("../myOptim/myBlackBoxOptim.jl")
# include("../myOptim/myCMAEvolutionStrategy.jl")

results_folder = "../results/obediab/optim"
# results_folder = "../results/obediab/bboptim"
# results_folder = "../results/obediab/cmaes"

dallaman_diab = "T2D model"
dallaman_norm = "normal model"


compartments = Dict(
     "GK"      => ["pk_1", "pk_2"],
     "IK"      => ["pV_I", "pm_1", "pm_5", "pm_6"], # we assume pHEb constant
     "Ra"      => ["pk_max", "pk_min", "pk_abs", "pk_gri", "pf", "pb", "pc"],
     "EGP"     => ["pk_p2", "pk_p3", "pk_p4", "pk_i"],
     "U"       => ["pV_m0", "pV_mx", "pxK_m0", "pp_2U"], # we assume pF_cns and pxK_mx constant
     "S"       => ["pK", "pxα_Y", "pxβ_Y"], # we assume pγ constant
     "RE"      => ["pk_e1", "pk_e2"],
     "DXRE"    => ["DXpk_e1","DXpk_e2"], 
     "IS"      => ["pEGPb", "pIb"] #, "pGb","pIb"] # init states
)

fitted_vn = ["DXp"]

free_pn = Vector{String}()
for c in keys(compartments)
  append!(free_pn, compartments[c])
end

tspan = (0.0,420.0)


# the glucose of OBEDIAB is about 22g of glucose and 32g of amidon
DM_params["pD"] = [54000.0,54000.0]

distdA = deserialize("../data/distdA")
distdB = deserialize("../data/distdB")

dataA_mean = deserialize("../data/dataA_mean")
dataB_mean = deserialize("../data/dataB_mean")
ob_d_A_Gp = dataA_mean[1,:]
ob_d_A_Ip = dataA_mean[2,:]
ob_d_A_DXp = dataA_mean[3,:]
ob_d_B_Gp = dataB_mean[1,:]
ob_d_B_Ip = dataB_mean[2,:]
ob_d_B_DXp = dataB_mean[3,:]


BWs_A = deserialize("../data/weightsA")
BW_A = mean([BWs_A[id][1] for id in keys(BWs_A)])

BWs_B = deserialize("../data/weightsB")
BW_B = mean([BWs_B[id][1] for id in keys(BWs_B)])
# Out:
# 132.98843239130437

# %%
################################################################
# Simulate data with normal and diabetic paramaters of Dalla Man
################################################################

t= [0.0,30.0,60.0,90.0,120.0,180.0]
time_points = Dict()
time_points["diab"] = t
time_points["norm"] = t

# compute init states for both normal and diabetic subject types
init_v = Dict(st => gen_init_states(all_p[st]) for st in ["norm","diab"])

# generate data points to fit 
sol = Dict(st => gen_solution(all_pn, all_p[st], all_vn, init_v[st], tspan, dalla_net!) for st in ["norm","diab"])

(G,I,EGP,Ra,DXp,U,S) = (Dict(), Dict(), Dict(), Dict(), Dict(), Dict(), Dict())
for st in ["norm", "diab"]
    (G[st],I[st],EGP[st],Ra[st],DXp[st],U[st],S[st]) = traces_of_obs_vars(sol[st],all_p[st])
end

# parameter estimation
DM_params["BW"] = [BW_A,BW_A]
lower, upper = lower_upper_bounds(DM_params, 1.5)
lower["pf"] = 0.5
upper["pf"] = 1.0
lower["pk_abs"] = 0.01 # otherwise 0 is computed

all_p["start"] = Dict(pn => all_p["diab"][pn] for pn in all_pn)

#all_p["start"]["pGb"] = ob_d_A_Gp[1]/all_p["start"]["pV_G"]
all_p["start"]["pIb"] = ob_d_A_Ip[1]/all_p["start"]["pV_I"]

init_v["start"] = gen_init_states(all_p["start"])

dataA = Array{Float64,2}(hcat(ob_d_A_DXp*10^3*DM_params["pV_G"][2]*10^(-1))')
prob = gen_prob(free_pn, all_pn, all_p["start"], all_vn, init_v["start"], tspan, dalla_net!)
resA = param_estim(free_pn, all_p["start"], fitted_vn, all_vn, lower, upper, time_points["diab"], distdA, prob, my_optimize)
;
# Out:
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# 26.67 secs, 6 evals, 3 steps, improv/step: 0.333 (last = 0.3333), fitness=51.346839622
# 27.18 secs, 63 evals, 35 steps, improv/step: 0.686 (last = 0.7188), fitness=47.545936611
# 53.79 secs, 67 evals, 37 steps, improv/step: 0.676 (last = 0.5000), fitness=47.545936611
# 67.23 secs, 115 evals, 68 steps, improv/step: 0.618 (last = 0.5484), fitness=47.545936611
# 80.69 secs, 133 evals, 83 steps, improv/step: 0.578 (last = 0.4000), fitness=47.494595257
# 93.55 secs, 140 evals, 89 steps, improv/step: 0.551 (last = 0.1667), fitness=47.494595257
# 118.94 secs, 144 evals, 91 steps, improv/step: 0.560 (last = 1.0000), fitness=47.494595257
# 131.63 secs, 154 evals, 99 steps, improv/step: 0.576 (last = 0.7500), fitness=47.494595257
# 144.91 secs, 218 evals, 153 steps, improv/step: 0.562 (last = 0.5370), fitness=46.499480525
# 157.84 secs, 241 evals, 173 steps, improv/step: 0.520 (last = 0.2000), fitness=46.499480525
# 170.70 secs, 263 evals, 191 steps, improv/step: 0.529 (last = 0.6111), fitness=46.499480525
# 183.58 secs, 264 evals, 192 steps, improv/step: 0.531 (last = 1.0000), fitness=46.499480525
# 196.57 secs, 286 evals, 213 steps, improv/step: 0.526 (last = 0.4762), fitness=46.499480525
# 209.57 secs, 287 evals, 214 steps, improv/step: 0.528 (last = 1.0000), fitness=46.499480525
# 222.90 secs, 311 evals, 237 steps, improv/step: 0.523 (last = 0.4783), fitness=46.499480525
# 235.68 secs, 316 evals, 242 steps, improv/step: 0.521 (last = 0.4000), fitness=46.499480525
# 249.86 secs, 321 evals, 247 steps, improv/step: 0.518 (last = 0.4000), fitness=46.499480525
# 264.01 secs, 325 evals, 250 steps, improv/step: 0.516 (last = 0.3333), fitness=46.499480525
# 278.58 secs, 327 evals, 252 steps, improv/step: 0.520 (last = 1.0000), fitness=46.499480525
# 292.72 secs, 367 evals, 286 steps, improv/step: 0.517 (last = 0.5000), fitness=46.499480525
# 306.45 secs, 368 evals, 287 steps, improv/step: 0.516 (last = 0.0000), fitness=46.499480525
# 320.79 secs, 370 evals, 289 steps, improv/step: 0.512 (last = 0.0000), fitness=46.499480525
# 336.29 secs, 380 evals, 299 steps, improv/step: 0.512 (last = 0.5000), fitness=46.499480525
# 696.03 secs, 1306 evals, 1227 steps, improv/step: 0.446 (last = 0.4800), fitness=45.189422783
# 711.11 secs, 1310 evals, 1231 steps, improv/step: 0.445 (last = 0.2500), fitness=45.189422783
# 725.22 secs, 1353 evals, 1274 steps, improv/step: 0.440 (last = 0.2791), fitness=45.189422783
# 738.11 secs, 1358 evals, 1279 steps, improv/step: 0.439 (last = 0.4000), fitness=45.189422783
# 751.26 secs, 1436 evals, 1357 steps, improv/step: 0.439 (last = 0.4359), fitness=45.058405393
# 763.95 secs, 1445 evals, 1366 steps, improv/step: 0.438 (last = 0.2222), fitness=45.058405393
# 776.63 secs, 1448 evals, 1369 steps, improv/step: 0.437 (last = 0.0000), fitness=45.058405393
# 789.32 secs, 1468 evals, 1390 steps, improv/step: 0.435 (last = 0.2857), fitness=45.058405393
# 801.92 secs, 1471 evals, 1393 steps, improv/step: 0.434 (last = 0.3333), fitness=45.058405393
# 814.64 secs, 1499 evals, 1421 steps, improv/step: 0.433 (last = 0.3571), fitness=45.058405393
# 827.34 secs, 1514 evals, 1436 steps, improv/step: 0.432 (last = 0.3333), fitness=45.058405393
# 827.84 secs, 1590 evals, 1512 steps, improv/step: 0.429 (last = 0.3816), fitness=45.015863057
# 840.50 secs, 1606 evals, 1528 steps, improv/step: 0.429 (last = 0.4375), fitness=45.015863057
# 853.24 secs, 1621 evals, 1543 steps, improv/step: 0.429 (last = 0.4000), fitness=45.015863057
# 853.75 secs, 1704 evals, 1626 steps, improv/step: 0.428 (last = 0.4096), fitness=44.982230569
# 866.44 secs, 1706 evals, 1628 steps, improv/step: 0.428 (last = 0.5000), fitness=44.982230569
# 879.22 secs, 1721 evals, 1643 steps, improv/step: 0.426 (last = 0.2000), fitness=44.982230569
# 892.37 secs, 1744 evals, 1666 steps, improv/step: 0.426 (last = 0.3913), fitness=44.982230569
# 905.27 secs, 1778 evals, 1700 steps, improv/step: 0.427 (last = 0.5000), fitness=44.932481153
# 918.30 secs, 1842 evals, 1764 steps, improv/step: 0.429 (last = 0.4688), fitness=44.929444373
# 918.80 secs, 1908 evals, 1830 steps, improv/step: 0.428 (last = 0.4242), fitness=44.929444373
# 919.31 secs, 1954 evals, 1876 steps, improv/step: 0.429 (last = 0.4348), fitness=44.929444373
# 932.10 secs, 1986 evals, 1908 steps, improv/step: 0.428 (last = 0.4062), fitness=44.929444373
# 945.35 secs, 2042 evals, 1964 steps, improv/step: 0.425 (last = 0.3214), fitness=44.926865213
# 957.87 secs, 2043 evals, 1965 steps, improv/step: 0.425 (last = 0.0000), fitness=44.926865213
# 958.37 secs, 2112 evals, 2035 steps, improv/step: 0.422 (last = 0.3286), fitness=44.918896663
# 958.87 secs, 2169 evals, 2092 steps, improv/step: 0.420 (last = 0.3684), fitness=44.870836719
# 971.62 secs, 2187 evals, 2110 steps, improv/step: 0.418 (last = 0.2222), fitness=44.870836719
# 972.14 secs, 2244 evals, 2167 steps, improv/step: 0.420 (last = 0.4737), fitness=44.870836719
# 2015.20 secs, 4395 evals, 4320 steps, improv/step: 0.387 (last = 0.5000), fitness=44.747380595
# 2034.21 secs, 4411 evals, 4336 steps, improv/step: 0.388 (last = 0.5625), fitness=44.747380595
# 2053.44 secs, 4419 evals, 4344 steps, improv/step: 0.387 (last = 0.1250), fitness=44.747380595
# 2071.38 secs, 4448 evals, 4373 steps, improv/step: 0.387 (last = 0.3793), fitness=44.746293706
# 2089.84 secs, 4458 evals, 4383 steps, improv/step: 0.388 (last = 0.6000), fitness=44.746293706
# 2109.27 secs, 4496 evals, 4421 steps, improv/step: 0.388 (last = 0.3947), fitness=44.746293706
# 2127.78 secs, 4512 evals, 4437 steps, improv/step: 0.388 (last = 0.3750), fitness=44.746293706
# 2128.28 secs, 4562 evals, 4487 steps, improv/step: 0.388 (last = 0.3600), fitness=44.745314723
# 2149.28 secs, 4580 evals, 4505 steps, improv/step: 0.387 (last = 0.2222), fitness=44.745314723
# 2171.84 secs, 4598 evals, 4523 steps, improv/step: 0.386 (last = 0.2778), fitness=44.745314723
# 2194.37 secs, 4620 evals, 4545 steps, improv/step: 0.386 (last = 0.3636), fitness=44.745314723
# 2194.87 secs, 4658 evals, 4583 steps, improv/step: 0.385 (last = 0.2632), fitness=44.744823299
# 2217.26 secs, 4661 evals, 4586 steps, improv/step: 0.385 (last = 0.3333), fitness=44.744823299
# 2239.66 secs, 4665 evals, 4590 steps, improv/step: 0.385 (last = 0.5000), fitness=44.744823299
# 2261.65 secs, 4683 evals, 4608 steps, improv/step: 0.385 (last = 0.1667), fitness=44.744823299
# 2262.16 secs, 4717 evals, 4642 steps, improv/step: 0.384 (last = 0.3235), fitness=44.744823299
# 2284.43 secs, 4730 evals, 4656 steps, improv/step: 0.384 (last = 0.2857), fitness=44.744823299
# 2306.61 secs, 4731 evals, 4657 steps, improv/step: 0.384 (last = 0.0000), fitness=44.744823299
# 2328.51 secs, 4737 evals, 4663 steps, improv/step: 0.384 (last = 0.3333), fitness=44.744823299
# 2350.54 secs, 4741 evals, 4667 steps, improv/step: 0.383 (last = 0.0000), fitness=44.744823299
# 2372.58 secs, 4750 evals, 4676 steps, improv/step: 0.383 (last = 0.4444), fitness=44.744823299
# 2393.36 secs, 4757 evals, 4683 steps, improv/step: 0.384 (last = 0.4286), fitness=44.743923666
# 2413.85 secs, 4771 evals, 4697 steps, improv/step: 0.383 (last = 0.2143), fitness=44.743923666
# 2414.43 secs, 4816 evals, 4742 steps, improv/step: 0.382 (last = 0.3111), fitness=44.743449362
# 2415.01 secs, 4856 evals, 4782 steps, improv/step: 0.381 (last = 0.2500), fitness=44.743422981
# 2435.62 secs, 4862 evals, 4788 steps, improv/step: 0.382 (last = 0.6667), fitness=44.743422981
# 2455.37 secs, 4864 evals, 4790 steps, improv/step: 0.381 (last = 0.0000), fitness=44.743422981
# 2475.78 secs, 4884 evals, 4810 steps, improv/step: 0.382 (last = 0.4500), fitness=44.741769767
# 2496.51 secs, 4900 evals, 4826 steps, improv/step: 0.381 (last = 0.2500), fitness=44.741769767
# 2516.90 secs, 4921 evals, 4847 steps, improv/step: 0.382 (last = 0.5238), fitness=44.741769767
# 2536.70 secs, 4935 evals, 4861 steps, improv/step: 0.381 (last = 0.1429), fitness=44.741769767
# 2537.22 secs, 4977 evals, 4903 steps, improv/step: 0.380 (last = 0.2381), fitness=44.741769767
# 2558.98 secs, 4995 evals, 4921 steps, improv/step: 0.380 (last = 0.3889), fitness=44.741769767
# 2580.27 secs, 5015 evals, 4941 steps, improv/step: 0.380 (last = 0.3000), fitness=44.740690804
# 2601.61 secs, 5021 evals, 4947 steps, improv/step: 0.380 (last = 0.5000), fitness=44.740690804
# 2623.56 secs, 5042 evals, 4968 steps, improv/step: 0.380 (last = 0.4762), fitness=44.739959819
# 2624.06 secs, 5060 evals, 4986 steps, improv/step: 0.380 (last = 0.2222), fitness=44.739959819
# 2646.17 secs, 5072 evals, 4998 steps, improv/step: 0.380 (last = 0.5000), fitness=44.739959819
# 2668.33 secs, 5083 evals, 5009 steps, improv/step: 0.379 (last = 0.0000), fitness=44.739959819
# 2689.98 secs, 5084 evals, 5010 steps, improv/step: 0.379 (last = 0.0000), fitness=44.739959819
# 2711.95 secs, 5086 evals, 5012 steps, improv/step: 0.379 (last = 0.0000), fitness=44.739959819
# 2733.05 secs, 5088 evals, 5014 steps, improv/step: 0.379 (last = 0.5000), fitness=44.739959819
# 2753.20 secs, 5099 evals, 5025 steps, improv/step: 0.379 (last = 0.3636), fitness=44.739959819
# 2774.82 secs, 5131 evals, 5057 steps, improv/step: 0.379 (last = 0.3750), fitness=44.739959819
# 2797.29 secs, 5163 evals, 5089 steps, improv/step: 0.378 (last = 0.3125), fitness=44.739959819
# 2818.82 secs, 5168 evals, 5094 steps, improv/step: 0.378 (last = 0.2000), fitness=44.739959819
# 2840.24 secs, 5171 evals, 5097 steps, improv/step: 0.378 (last = 0.0000), fitness=44.739959819
# 2840.75 secs, 5214 evals, 5140 steps, improv/step: 0.378 (last = 0.4186), fitness=44.739734397
# 2841.26 secs, 5247 evals, 5173 steps, improv/step: 0.378 (last = 0.3333), fitness=44.739734397
# 2862.09 secs, 5248 evals, 5174 steps, improv/step: 0.378 (last = 0.0000), fitness=44.739734397
# 2882.75 secs, 5260 evals, 5186 steps, improv/step: 0.378 (last = 0.1667), fitness=44.739734397
# 2903.02 secs, 5269 evals, 5195 steps, improv/step: 0.378 (last = 0.4444), fitness=44.739734397
# 2922.49 secs, 5276 evals, 5202 steps, improv/step: 0.378 (last = 0.4286), fitness=44.739734397
# 2923.15 secs, 5299 evals, 5225 steps, improv/step: 0.378 (last = 0.4783), fitness=44.739734397
# 2943.26 secs, 5322 evals, 5248 steps, improv/step: 0.378 (last = 0.3043), fitness=44.739734397
# 2959.57 secs, 5329 evals, 5255 steps, improv/step: 0.378 (last = 0.1429), fitness=44.739734397
# 2980.84 secs, 5331 evals, 5257 steps, improv/step: 0.377 (last = 0.0000), fitness=44.739734397
# 3000.52 secs, 5336 evals, 5262 steps, improv/step: 0.377 (last = 0.2000), fitness=44.739734397
# 3004.30 secs, 5349 evals, 5275 steps, improv/step: 0.378 (last = 0.5385), fitness=44.739734397
# 3023.65 secs, 5351 evals, 5277 steps, improv/step: 0.377 (last = 0.0000), fitness=44.739734397
# 3024.73 secs, 5359 evals, 5285 steps, improv/step: 0.378 (last = 0.6250), fitness=44.739734397
# 3044.55 secs, 5361 evals, 5287 steps, improv/step: 0.378 (last = 0.5000), fitness=44.739578277
# 3063.97 secs, 5373 evals, 5299 steps, improv/step: 0.378 (last = 0.4167), fitness=44.739578277
# 3081.27 secs, 5375 evals, 5301 steps, improv/step: 0.378 (last = 0.0000), fitness=44.739578277
# 3100.45 secs, 5377 evals, 5303 steps, improv/step: 0.378 (last = 0.5000), fitness=44.739578277
# 3119.27 secs, 5395 evals, 5321 steps, improv/step: 0.378 (last = 0.4444), fitness=44.739578277
# 3141.88 secs, 5409 evals, 5335 steps, improv/step: 0.378 (last = 0.2857), fitness=44.739578277
# 3163.50 secs, 5414 evals, 5340 steps, improv/step: 0.378 (last = 0.2000), fitness=44.739578277
# 3182.01 secs, 5426 evals, 5352 steps, improv/step: 0.377 (last = 0.1667), fitness=44.739578277
# 3201.45 secs, 5441 evals, 5367 steps, improv/step: 0.377 (last = 0.2667), fitness=44.739578277
# 3225.23 secs, 5445 evals, 5371 steps, improv/step: 0.377 (last = 0.0000), fitness=44.739578277
# 3226.40 secs, 5453 evals, 5379 steps, improv/step: 0.377 (last = 0.3750), fitness=44.739330311
# 3226.91 secs, 5485 evals, 5411 steps, improv/step: 0.377 (last = 0.4375), fitness=44.739330311
# 3227.63 secs, 5506 evals, 5432 steps, improv/step: 0.378 (last = 0.6190), fitness=44.738819814
# 3229.03 secs, 5528 evals, 5454 steps, improv/step: 0.378 (last = 0.3636), fitness=44.738819814
# 3247.77 secs, 5543 evals, 5469 steps, improv/step: 0.378 (last = 0.2667), fitness=44.738819814
# 3269.92 secs, 5564 evals, 5490 steps, improv/step: 0.378 (last = 0.4762), fitness=44.738819814
# 3274.30 secs, 5570 evals, 5496 steps, improv/step: 0.378 (last = 0.3333), fitness=44.738672425
# 3278.32 secs, 5578 evals, 5504 steps, improv/step: 0.378 (last = 0.2500), fitness=44.738131564
# 3298.02 secs, 5614 evals, 5540 steps, improv/step: 0.378 (last = 0.4444), fitness=44.737876008
# 3318.23 secs, 5621 evals, 5547 steps, improv/step: 0.378 (last = 0.4286), fitness=44.737876008
# 3336.82 secs, 5643 evals, 5569 steps, improv/step: 0.378 (last = 0.4091), fitness=44.737876008
# 3354.41 secs, 5654 evals, 5580 steps, improv/step: 0.378 (last = 0.3636), fitness=44.737876008
# 3371.96 secs, 5660 evals, 5586 steps, improv/step: 0.378 (last = 0.3333), fitness=44.737876008
# 3389.48 secs, 5671 evals, 5597 steps, improv/step: 0.378 (last = 0.4545), fitness=44.737876008
# 3406.90 secs, 5686 evals, 5612 steps, improv/step: 0.378 (last = 0.4000), fitness=44.736908847
# 3407.91 secs, 5696 evals, 5622 steps, improv/step: 0.378 (last = 0.3000), fitness=44.736908847
# 3430.22 secs, 5697 evals, 5623 steps, improv/step: 0.378 (last = 0.0000), fitness=44.736908847
# 3452.07 secs, 5699 evals, 5625 steps, improv/step: 0.378 (last = 0.5000), fitness=44.736908847
# 3471.70 secs, 5717 evals, 5643 steps, improv/step: 0.378 (last = 0.2222), fitness=44.736908847
# 3494.38 secs, 5734 evals, 5660 steps, improv/step: 0.378 (last = 0.4118), fitness=44.736644142
# 3494.89 secs, 5775 evals, 5701 steps, improv/step: 0.378 (last = 0.4390), fitness=44.736644142
# 3516.56 secs, 5783 evals, 5709 steps, improv/step: 0.379 (last = 0.7500), fitness=44.735670739
# 3537.85 secs, 5789 evals, 5715 steps, improv/step: 0.379 (last = 0.6667), fitness=44.735670739
# 3558.32 secs, 5800 evals, 5726 steps, improv/step: 0.379 (last = 0.2727), fitness=44.735670739
# 3580.77 secs, 5833 evals, 5759 steps, improv/step: 0.379 (last = 0.3333), fitness=44.735670739
# 3601.63 secs, 5869 evals, 5795 steps, improv/step: 0.379 (last = 0.3889), fitness=44.735670739
# 3622.78 secs, 5907 evals, 5833 steps, improv/step: 0.378 (last = 0.2895), fitness=44.735670739
# 3642.89 secs, 5909 evals, 5835 steps, improv/step: 0.378 (last = 0.0000), fitness=44.735670739
# 3662.61 secs, 5957 evals, 5883 steps, improv/step: 0.377 (last = 0.2292), fitness=44.735670739
# 3682.01 secs, 5995 evals, 5921 steps, improv/step: 0.377 (last = 0.3947), fitness=44.735670739
# 3682.51 secs, 6004 evals, 5930 steps, improv/step: 0.377 (last = 0.5556), fitness=44.735670739
# 3701.80 secs, 6040 evals, 5966 steps, improv/step: 0.377 (last = 0.3333), fitness=44.735670739
# 3721.10 secs, 6060 evals, 5986 steps, improv/step: 0.377 (last = 0.5000), fitness=44.735582298
# 3740.25 secs, 6069 evals, 5995 steps, improv/step: 0.377 (last = 0.2222), fitness=44.735582298
# 3743.12 secs, 6072 evals, 5998 steps, improv/step: 0.377 (last = 0.3333), fitness=44.735582298
# 3761.71 secs, 6076 evals, 6002 steps, improv/step: 0.377 (last = 0.2500), fitness=44.735582298
# 3762.94 secs, 6085 evals, 6011 steps, improv/step: 0.377 (last = 0.4444), fitness=44.735582298
# 3782.03 secs, 6120 evals, 6047 steps, improv/step: 0.377 (last = 0.3056), fitness=44.735582298
# 3782.55 secs, 6176 evals, 6103 steps, improv/step: 0.377 (last = 0.3571), fitness=44.735582298
# 3783.05 secs, 6207 evals, 6134 steps, improv/step: 0.376 (last = 0.3548), fitness=44.735582298
# 3802.46 secs, 6213 evals, 6140 steps, improv/step: 0.376 (last = 0.1667), fitness=44.735582298
# 3802.97 secs, 6266 evals, 6194 steps, improv/step: 0.377 (last = 0.4630), fitness=44.735582298
# 3822.63 secs, 6314 evals, 6242 steps, improv/step: 0.377 (last = 0.4375), fitness=44.735465463
# 4734.40 secs, 7219 evals, 7147 steps, improv/step: 0.371 (last = 0.2500), fitness=44.734274093
# 4750.70 secs, 7235 evals, 7163 steps, improv/step: 0.372 (last = 0.5625), fitness=44.734274093
# 4753.43 secs, 7237 evals, 7165 steps, improv/step: 0.372 (last = 0.5000), fitness=44.734274093
# 4755.72 secs, 7240 evals, 7168 steps, improv/step: 0.372 (last = 0.3333), fitness=44.734274093
# 4772.77 secs, 7250 evals, 7178 steps, improv/step: 0.372 (last = 0.5000), fitness=44.734098608
# 4775.83 secs, 7264 evals, 7192 steps, improv/step: 0.372 (last = 0.2857), fitness=44.734098608
# 4794.95 secs, 7285 evals, 7213 steps, improv/step: 0.372 (last = 0.5714), fitness=44.734098608
# 4815.19 secs, 7316 evals, 7244 steps, improv/step: 0.373 (last = 0.4194), fitness=44.733823432
# 4836.06 secs, 7319 evals, 7247 steps, improv/step: 0.373 (last = 0.6667), fitness=44.733823432
# 4853.61 secs, 7338 evals, 7266 steps, improv/step: 0.373 (last = 0.4211), fitness=44.733776708
# 4870.73 secs, 7350 evals, 7278 steps, improv/step: 0.373 (last = 0.3333), fitness=44.733776708
# 4887.81 secs, 7354 evals, 7282 steps, improv/step: 0.373 (last = 0.2500), fitness=44.733776708
# 4888.33 secs, 7361 evals, 7289 steps, improv/step: 0.373 (last = 0.4286), fitness=44.733776708
# 4907.55 secs, 7372 evals, 7300 steps, improv/step: 0.373 (last = 0.3636), fitness=44.733776708
# 4921.59 secs, 7379 evals, 7307 steps, improv/step: 0.373 (last = 0.4286), fitness=44.733776708
# 4940.23 secs, 7384 evals, 7312 steps, improv/step: 0.373 (last = 0.2000), fitness=44.733776708
# 4958.89 secs, 7394 evals, 7322 steps, improv/step: 0.372 (last = 0.2000), fitness=44.733776708
# 4966.05 secs, 7407 evals, 7335 steps, improv/step: 0.372 (last = 0.2308), fitness=44.733776708
# 4984.75 secs, 7435 evals, 7363 steps, improv/step: 0.372 (last = 0.3929), fitness=44.733776708
# 5003.35 secs, 7440 evals, 7368 steps, improv/step: 0.372 (last = 0.2000), fitness=44.733776708
# 5022.02 secs, 7442 evals, 7370 steps, improv/step: 0.372 (last = 0.0000), fitness=44.733776708
# 5041.31 secs, 7447 evals, 7375 steps, improv/step: 0.372 (last = 0.2000), fitness=44.733776708
# 5059.87 secs, 7449 evals, 7377 steps, improv/step: 0.372 (last = 0.0000), fitness=44.733776708
# 5078.25 secs, 7452 evals, 7380 steps, improv/step: 0.372 (last = 0.3333), fitness=44.733776708
# 5099.62 secs, 7456 evals, 7384 steps, improv/step: 0.372 (last = 0.2500), fitness=44.733776708
# 5118.23 secs, 7477 evals, 7405 steps, improv/step: 0.371 (last = 0.2381), fitness=44.733776708
# 5137.01 secs, 7482 evals, 7410 steps, improv/step: 0.371 (last = 0.4000), fitness=44.733776708
# 5156.60 secs, 7494 evals, 7422 steps, improv/step: 0.372 (last = 0.5833), fitness=44.733629929
# 5174.90 secs, 7496 evals, 7424 steps, improv/step: 0.372 (last = 0.0000), fitness=44.733629929
# 5193.86 secs, 7507 evals, 7435 steps, improv/step: 0.371 (last = 0.2727), fitness=44.733629929
# 5211.47 secs, 7513 evals, 7441 steps, improv/step: 0.372 (last = 0.5000), fitness=44.733629929
# 5230.04 secs, 7515 evals, 7443 steps, improv/step: 0.371 (last = 0.0000), fitness=44.733629929
# 5248.24 secs, 7553 evals, 7481 steps, improv/step: 0.372 (last = 0.3947), fitness=44.733629929
# 5266.63 secs, 7566 evals, 7494 steps, improv/step: 0.371 (last = 0.0769), fitness=44.733629929
# 5285.17 secs, 7572 evals, 7500 steps, improv/step: 0.371 (last = 0.0000), fitness=44.733629929
# 5303.15 secs, 7577 evals, 7505 steps, improv/step: 0.371 (last = 0.6000), fitness=44.733629929
# 5303.65 secs, 7634 evals, 7562 steps, improv/step: 0.371 (last = 0.3509), fitness=44.733629929
# 5321.72 secs, 7646 evals, 7574 steps, improv/step: 0.371 (last = 0.4167), fitness=44.733629929
# 5322.23 secs, 7667 evals, 7595 steps, improv/step: 0.371 (last = 0.2857), fitness=44.733629929
# 5340.01 secs, 7671 evals, 7599 steps, improv/step: 0.371 (last = 0.2500), fitness=44.733629929
# 5359.83 secs, 7672 evals, 7600 steps, improv/step: 0.371 (last = 0.0000), fitness=44.733629929
# 5379.96 secs, 7677 evals, 7605 steps, improv/step: 0.370 (last = 0.2000), fitness=44.733629929
# 5398.57 secs, 7724 evals, 7652 steps, improv/step: 0.371 (last = 0.4043), fitness=44.733629929
# 5417.85 secs, 7767 evals, 7695 steps, improv/step: 0.371 (last = 0.3953), fitness=44.733575525
# 5437.08 secs, 7781 evals, 7709 steps, improv/step: 0.371 (last = 0.5714), fitness=44.733575525
# 5438.06 secs, 7824 evals, 7752 steps, improv/step: 0.372 (last = 0.4651), fitness=44.733575525
# 5456.43 secs, 7834 evals, 7762 steps, improv/step: 0.372 (last = 0.4000), fitness=44.733575525
# 5475.87 secs, 7836 evals, 7764 steps, improv/step: 0.372 (last = 0.5000), fitness=44.733575525
# 5494.60 secs, 7839 evals, 7767 steps, improv/step: 0.372 (last = 0.3333), fitness=44.733575525
# 5510.64 secs, 7881 evals, 7809 steps, improv/step: 0.371 (last = 0.3333), fitness=44.733574424
# ┌ Warning: Optimization interrupted, recovering intermediate results...
# └ @ BlackBoxOptim /home/danilo/.julia/packages/BlackBoxOptim/iWqGG/src/opt_controller.jl:482

# %%
# plotting results
comp = "visitA"

figs = Dict()
figs[comp] = Dict()

estimated_params = best_params(resA)
all_p[comp] = update_params(free_pn, estimated_params, all_pn, all_p["start"])

init_v[comp] = gen_init_states(all_p[comp])
sol[comp] = gen_solution(all_pn, all_p[comp], all_vn, init_v[comp], tspan, dalla_net!)

(G[comp],I[comp],EGP[comp],Ra[comp],DXp[comp],U[comp],S[comp]) = traces_of_obs_vars(sol[comp],all_p[comp])

VarGly3A = ob_d_A_Gp / DM_params["pV_G"][2]
VarIns3A = ob_d_A_Ip / DM_params["pV_I"][2]

for (var,svar,ylabel) in zip((G,I,EGP,Ra,DXp,U,S),("G","I","EGP","Ra","DXp","U","S"),("(mg/dL)", "(pmol/l)", "(mg/kg/min)", "(mg/kg/min)", "(mg/kg/min)", "(mg/kg/min)", "(pmol/kg/min)"))
    figs[comp][svar] = plot(sol[comp].t, var[comp], title = svar, linecolor = :blue, xlabel = "time (min)", ylabel = ylabel, labels = "\"Visit A\" model", ylims = (0,maximum([maximum(var[comp]),maximum(var["diab"])])))
    if(svar == "G")
       plot!(t,VarGly3A, linecolor = :red, labels = "\"Visit A\" data")
    #    plot!(sol["diab"].t, var["diab"], labels = "T2D model",ylims = (0,maximum([maximum(var[comp]),maximum(var["diab"]),maximum(VarGly3A)])))
       plot!(sol["diab"].t, var["diab"], labels = dallaman_diab, linecolor = :black, ylims = (0,maximum([maximum(var[comp]),maximum(var["diab"]),maximum(VarGly3A)])))
    elseif(svar == "I")
        plot!(t,VarIns3A, linecolor = :red, labels = "\"Visit A\" data")
        # plot!(sol["diab"].t, var["diab"], labels = "T2D model",ylims = (0,maximum([maximum(var[comp]),maximum(var["diab"]),maximum(VarIns3A)])))
        plot!(sol["diab"].t, var["diab"], labels = dallaman_diab, linecolor = :black, ylims = (0,maximum([maximum(var[comp]),maximum(var["diab"]),maximum(VarIns3A)])))
    else
        # plot!(sol["diab"].t, var["diab"], labels = "T2D model")
        plot!(sol["diab"].t, var["diab"], labels = dallaman_diab, linecolor = :black)
    end
end

figs[comp]["all"] = plot(figs[comp]["G"],figs[comp]["I"],figs[comp]["EGP"],figs[comp]["Ra"],figs[comp]["DXp"],figs[comp]["U"],figs[comp]["S"],size=(1000,800))
#savefig(figs[comp]["all"],results_folder*"/$(comp).png")

#lv = loss_value(resA) 
#resultsA = DataFrame(Param = free_pn, vals = estimated_params) 
#push!(resultsA, ["loss", lv])

#CSV.write(results_folder*"/resultsA.csv",resultsA)

# %%
###############################################
# Now we estimate all the parameters to match the visit B starting from the parameters we just estimated from visit A
###############################################
DM_params["BW"] = [BW_B,BW_B]

all_p["start"] = copy(all_p["visitA"])
all_p["start"]["pIb"] = ob_d_B_Ip[1]/all_p["start"]["pV_I"]

init_v["start"] = gen_init_states(all_p["start"])

dataB = Array{Float64,2}(hcat(ob_d_B_Gp, ob_d_B_Ip)')

# for comp in keys(compartments)
prob = gen_prob(free_pn, all_pn, all_p["start"], all_vn, init_v["start"], tspan, dalla_net!)
resB = param_estim(free_pn, all_p["start"], fitted_vn, all_vn, lower, upper, time_points["diab"], distdB, prob, my_optimize)

# plotting results
comp = "visitB"

figs[comp] = Dict()

estimated_params = best_params(resB)
all_p[comp] = update_params(free_pn, estimated_params, all_pn, all_p["start"])

init_v[comp] = gen_init_states(all_p[comp])
sol[comp] = gen_solution(all_pn, all_p[comp], all_vn, init_v[comp], tspan, dalla_net!)

(G[comp],I[comp],EGP[comp],Ra[comp],U[comp],S[comp]) = traces_of_obs_vars(sol[comp],all_p[comp])

VarGly3B = ob_d_B_Gp / DM_params["pV_G"][2]
VarIns3B = ob_d_B_Ip / DM_params["pV_I"][2]

for (var,svar,ylabel) in zip((G,I,EGP,Ra,U,S),("G","I","EGP","Ra","U","S"),("(mg/dL)", "(pmol/l)", "(mg/kg/min)", "(mg/kg/min)", "(mg/kg/min)", "(pmol/kg/min)"))
    figs[comp][svar] = plot(sol[comp].t, var[comp], title = svar, linecolor=:green, xlabel = "time (min)", ylabel = "G (mg/dL)", labels = "\"Visit B\" model", ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"])])))
    if(svar == "G")
        plot!(t,VarGly3B, linecolor=:red, labels = "\"Visit B\" data")
        plot!(sol["visitA"].t, var["visitA"], linecolor=:blue, labels = "\"Visit A\" model",ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"]),maximum(VarGly3B)])))
    elseif(svar == "I")
        plot!(t,VarIns3B, linecolor=:red, labels = "\"Visit B\" data")
        plot!(sol["visitA"].t, var["visitA"], linecolor=:blue, labels = "\"Visit A\" model",ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"]),maximum(VarIns3B)])))
    else
        plot!(sol["visitA"].t, var["visitA"], linecolor=:blue, labels = "\"Visit A\" model")
    end
end

figs[comp]["all"] = plot(figs[comp]["G"],figs[comp]["I"],figs[comp]["EGP"],figs[comp]["Ra"],figs[comp]["U"],figs[comp]["S"],size=(1000,800) ,layout = (3,2))
savefig(figs[comp]["all"],results_folder*"/$(comp).png")

lv = loss_value(resB) 
resultsB = DataFrame(Param = free_pn, vals = estimated_params) 
push!(resultsB, ["loss", lv])

CSV.write(results_folder*"/resultsB.csv",resultsB)

# %%
###############################################
# parameter estimation compartment by compartment from estimated visitA to match visitB
###############################################

compartments = Dict(
     "GK+U" => ["pk_1", "pk_2", "pV_m0", "pV_mx", "pxK_m0", "pp_2U", "pIb", "pEGPb"],
     "IK+S" => ["pV_I", "pm_1", "pm_5", "pm_6", "pK", "pxα_Y", "pxβ_Y", "pIb", "pEGPb"], # we assume pHEb constant
     "Ra"   => ["pk_max", "pk_min", "pk_abs", "pk_gri", "pf", "pb", "pc", "pIb", "pEGPb"],
     "EGP"  => ["pk_p2", "pk_p3", "pk_p4", "pk_i", "pIb", "pEGPb"],
     "RE"   => ["pk_e1", "pk_e2", "pIb", "pEGPb"],
)

for comp in keys(compartments)
    figs[comp] = Dict()
end

probs = Dict()
res = Dict()

dataB = Array{Float64,2}(hcat(ob_d_B_Gp, ob_d_B_Ip)')

for comp in keys(compartments)
    probs[comp] = gen_prob(compartments[comp], all_pn, all_p["visitA"], all_vn, init_v["visitA"], tspan, dalla_net!)
    res[comp] = param_estim(compartments[comp], all_p["visitA"], fitted_vn, all_vn, lower, upper, time_points["diab"], distdB, probs[comp], my_optimize)

    estimated_params = best_params(res[comp])
    all_p[comp] = update_params(compartments[comp], estimated_params, all_pn, all_p["visitA"])
    init_v[comp] = gen_init_states(all_p[comp])
    sol[comp] = gen_solution(all_pn, all_p[comp], all_vn, init_v[comp], tspan, dalla_net!)

    (G[comp],I[comp],EGP[comp],Ra[comp],U[comp],S[comp]) = traces_of_obs_vars(sol[comp],all_p[comp])

    VarGly3 = ob_d_B_Gp / DM_params["pV_G"][2]
    VarIns3 = ob_d_B_Ip / DM_params["pV_I"][2]

    for (var,svar,ylabel) in zip((G,I,EGP,Ra,U,S),("G","I","EGP","Ra","U","S"),("(mg/dL)", "(pmol/l)", "(mg/kg/min)", "(mg/kg/min)", "(mg/kg/min)", "(pmol/kg/min)"))
        # figs[comp][svar] = plot(sol[comp].t, var[comp], linecolor = :green, title = svar, xlabel = "time (min)", ylabel = ylabel, labels = "\"Visit B\" model", ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"])])))
        figs[comp][svar] = plot(sol[comp].t, var[comp], linecolor = :blue, linestyle = :dash, title = svar, xlabel = "time (min)", ylabel = ylabel, labels = "\"Visit B\" model", ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"])])))
        if(svar == "G")
            # plot!(sol["visitA"].t, var["visitA"], linecolor = :blue, labels = "\"Visit A\" model",ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"]),maximum(VarGly3)])))
            plot!(sol["visitA"].t, var["visitA"], linecolor = :red, labels = "\"Visit A\" model",ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"]),maximum(VarGly3)])))
            # plot!(t,VarGly3, linecolor = :red, labels = "\"Visit B\" data")
            plot!(t,VarGly3, linecolor = :green, labels = "\"Visit B\" data")
         elseif(svar == "I")
            # plot!(sol["visitA"].t, var["visitA"], linecolor = :blue, labels = "\"Visit A\" model",ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"]),maximum(VarIns3)])))
            plot!(sol["visitA"].t, var["visitA"], linecolor = :red, labels = "\"Visit A\" model",ylims = (0,maximum([maximum(var[comp]),maximum(var["visitA"]),maximum(VarIns3)])))
            # plot!(t,VarIns3, linecolor = :red, labels = "\"Visit B\" data")
            plot!(t,VarIns3, linecolor = :green, labels = "\"Visit B\" data")
         else
            #  plot!(sol["visitA"].t, var["visitA"], linecolor = :blue, labels = "\"Visit A\" model")
             plot!(sol["visitA"].t, var["visitA"], linecolor = :red, labels = "\"Visit A\" model")
         end     
    end    

    figs[comp]["all"] = plot(figs[comp]["G"],figs[comp]["I"],figs[comp]["EGP"],figs[comp]["Ra"],figs[comp]["U"],figs[comp]["S"],size=(1000,800) ,layout = (3,2))
    savefig(figs[comp]["all"],results_folder*"/$comp.png")
end

# save parameter values in csv file
for comp in keys(compartments)
    local estimated_params = best_params(res[comp])
    local lv = loss_value(res[comp])
    DFresults = DataFrame(Param = compartments[comp], vals = estimated_params)
    push!(DFresults, ["loss", lv])

    CSV.write(results_folder*"/$comp.csv",DFresults)
end

# save loss results
compartments_names = [n for n in keys(compartments)]
results = [loss_value(res[comp]) for comp in compartments_names]
comparaisons = bar(compartments_names,results,labels = nothing ,title = "Log Likelihood Minimization by Biological Function" )
savefig(comparaisons,results_folder*"/loss.png")


f_iks = plot(figs["IK+S"]["G"],figs["IK+S"]["I"],figs["IK+S"]["Ra"],size=(1100,150) ,layout = (1,3))
f_ra = plot(figs["Ra"]["G"],figs["Ra"]["I"],figs["Ra"]["Ra"],size=(1100,150) ,layout = (1,3))
f_visita = plot(figs["visitA"]["G"],figs["visitA"]["I"],figs["visitA"]["Ra"],size=(1100,150) ,layout = (1,3))
f_visitb = plot(figs["visitB"]["G"],figs["visitB"]["I"],figs["visitB"]["Ra"],size=(1100,150) ,layout = (1,3))

savefig(f_iks,results_folder*"/IKS_GIRa.png")
savefig(f_ra,results_folder*"/Ra_GIRa.png")
savefig(f_visita,results_folder*"/VisitA_GIRa.png")
savefig(f_visitb,results_folder*"/VisitB_GIRa.png")
